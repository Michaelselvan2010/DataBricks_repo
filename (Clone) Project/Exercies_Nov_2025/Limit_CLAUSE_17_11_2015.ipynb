# %%
# %sql
SELECT * FROM POPULATION;

SELECT * FROM POPULATION WHERE COUNTRY NOT IN ('INDIA','U.S.A');


SELECT * FROM POPULATION WHERE TOTAL_POPULATION <2000;

SELECT * FROM POPULATION WHERE TOTAL_POPULATION >2000;


SELECT * FROM POPULATION WHERE TOTAL_POPULATION BETWEEN 78880 AND 78899;

SELECT * FROM POPULATION WHERE COUNTRY LIKE 'I_D%';

SELECT * FROM POPULATION WHERE COUNTRY='INDIA' AND TOTAL_POPULATION=3343;

# %%
# %sql
SELECT * FROM POPULATION WHERE COUNTRY NOT IN ('USA','INDIA');

# %%
# %sql
SELECT UPPER('michaelselvan');

SELECT * FROM POPULATION;


SELECT LOWER(COUNTRY) FROM POPULATION WHERE COUNTRY='PAKISTIAN';

SELECT TRIM('S   SQL    H');


SELECT REPLACE('THIS IS SQL COURSE','SQL','PYTHON');
