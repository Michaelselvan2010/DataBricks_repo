# %%
##df=spark.sql("SELECT * FROM default.population ORDER BY TOTAL_POPULATION DESC")
##display(df)

#df=spark.sql("SELECT * FROM POPULATION  WHERE COUNTRY='INDIA' ORDER BY CONTINENT ASC LIMIT 3")
#display(df)


##df=spark.sql("SELECT * FROM POPULATION WHERE TOTAL_POPULATION < 2000")
##display(df)


df=spark.sql("SELECT * FROM POPULATION WHERE TOTAL_POPULATION BETWEEN 78880 AND 78899")
display(df)
