# %%
form pyspark.sql import SparkSession

spark= SparkSession.builder.getApp("test").getOrCreate()


df=spark.read.csv("/workspace/data.csv")

df.createOrRelace("Test")
df=spark.sql("select ID,Emp_id,DOB,Designation,update_at, 'StartDate:' startDate || 'End Date:' Enddate ||  from Test")



sparl.write("newTable")

=========================================================


Input:
 
ID	Emp_id	DOB		Designation		update_at

1	AA	10/1/1999	Trainee			10th july 2022

2	AA	10/1/1999	Associate		11th june 2023

3	AA	10/1/1999	sr.Associate		11th May 2024

2	BB	10/1/1995	SE			10th july 2022

3	BB	10/1/1995	Associate		15th july 2023

4	CC	10/5/1996	Trainee			10th july 2022

5	CC	10/1/1999	Trainee			5th jan 2023

8	QQ	10/1/1998	Trainee			10th july 2022

7	DD	10/1/1985	President		10th july 2022

65	DD	10/1/1985	VP			8th may 2023

 
DLT, AZURE BUNDEL
Output: 

ID	Emp_id	DOB	Designation	update_at	start_date	end_date	is_active

1	AA	10/1/1999	Trainee	10th july 2022	10th july 2022	11th june 2023	N

2	AA	10/1/1999	Associate	11th june 2023	11th june 2023	11th May 2024	N

3	AA	10/1/1999	sr.Associate	11th May 2024	11th May 2024	null	Y

10	BB	10/1/1995	SE	10th july 2022	10th july 2022	15th july 2023	N

11	BB	10/1/1995	Associate	15th july 2023	15th july 2023	null	Y

4	CC	10/5/1996	Trainee	10th july 2022	10th july 2022	5th jan 2023	N

5	CC	10/1/1999	Trainee	5th jan 2023	5th jan 2023	Null	Y

8	QQ	10/1/1998	Trainee	10th july 2022	10th july 2022	null	Y

7	DD	10/1/1985	President	10th july 2022	10th july 2022	8th may 2023	N

65	DD	10/1/1985	VP	8th may 2023	8th may 2023	null	Y
