# %%
from datetime import datetime, date
import pandas as pd
from pyspark.sql import Row
from pyspark.sql import SparkSession

spark = SparkSession.builder.getOrCreate()

authors = spark.read.option('header', 'true').option('inferSchema', 'true').csv('dbfs:/Volumes/sparkcatalog/default/practical/Data.csv', sep=',')

df = spark.createDataFrame(pd.read_csv('dbfs:/Volumes/sparkcatalog/default/practical/Data.csv'))
df

df.show()

df.printSchema()
